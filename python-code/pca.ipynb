# %% [markdown]
# What is PCA in Simple Terms?
# Principal Component Analysis (PCA) is like summarizing a big book. Imagine you have a book with a lot of information, but you only want the key points. PCA helps you find those key points (principal components) from a lot of data.
#
# Why Use PCA?
# Simplify Data:
# If you have too much information (features), PCA helps reduce it to the most important parts.
# Remove Redundancy:
# It helps get rid of repetitive information, making your data cleaner.
# Visualization:
# It helps in visualizing high-dimensional data in two or three dimensions.
# How Does PCA Work?
# Standardize Data:
# Make sure all data is on the same scale.
# Find Principal Components:
# These are the directions in which your data varies the most.
# Transform Data:
# Project your data onto these principal components, reducing the number of features.
# Simple Example
# Imagine you have data about students' scores in different subjects. You want to understand overall performance without looking at every single subject:
#
# Collect Scores:
# Scores in Math, Science, English, etc.
# Standardize Scores:
# Make sure all scores are comparable.
# Apply PCA:
# Find the key components that capture the most information about students' performance.
# Reduce Data:
# Instead of looking at scores in ten subjects, you now look at two main components.
# How to Use PCA
# Standardize Your Data:
# Make all features (like age, income) have similar importance.
# Apply PCA:
# Use a library like scikit-learn in Python to find the principal components.
# Transform Your Data:
# Use these components to simplify your data.
#
# Key Points:
# Standardization: Essential for PCA to ensure each feature contributes equally to the analysis.
# Principal Components: The new variables that capture the maximum variance.
# Explained Variance: Indicates the importance of each component.
# Visualization: Helps in understanding the transformed data.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# Standardize the data
x = StandardScaler().fit_transform(data)

# Perform PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(x)
principal_df = pd.DataFrame(data=principal_components, columns=['Principal Component 1', 'Principal Component 2'])

# Explained variance
explained_variance = pca.explained_variance_ratio_
print('Explained variance by components:', explained_variance)

# Visualize the results
plt.figure(figsize=(8,6))
plt.scatter(principal_df['Principal Component 1'], principal_df['Principal Component 2'], c=iris.target)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2 component PCA')
plt.show()
# Out:
# Explained variance by components: [0.72962445 0.22850762]
